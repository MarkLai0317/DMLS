# %% [markdown]
# # CIFAR-100 Image Classification using ResNet (Residual Network) in PyTorch
#
# ResNet, short for Residual Network is a specific type of neural network that was introduced in 2015 by Kaiming He, Xiangyu Zhang, Shaoqing Ren and Jian Sun in their paper [“Deep Residual Learning for Image Recognition”](https://arxiv.org/pdf/1512.03385.pdf). <br/>
# ResNet was an innovative approach over VGG-like models:
# * Won 1st place in the ILSVRC 2015 classification competition with a top-5 error rate of 3.57% (An ensemble model)
# * Won the 1st place in ILSVRC and COCO 2015 competition in ImageNet Detection, ImageNet localization, Coco detection and Coco segmentation.
# * Replacing VGG-16 layers in Faster R-CNN with ResNet-101. They observed relative improvements of 28%
# * Efficiently trained networks with 100 layers and 1000 layers also.
#
# We get over 70% accuracy without using any pre-trained model in 100 epochs and it proves the power of ResNet.
#
# In this notebook, I will be implementing less complex version of ResNets to be able to get results in reasonable amount of time. Even though the implementation is done through CIFAR-100 dataset, it can be used with any image classification dataset. <br/>Note: Do not forget to change transform values if you use different the dataset. You can find the best parameters from SOTA implementations for well-known datasets.
#
# #### References which I got implementations and explanations.
# - [weiaicunzai/pytorch-cifar100](https://github.com/weiaicunzai/pytorch-cifar100/blob/master/models/resnet.py)
# - [papers-with-code](https://paperswithcode.com/sota/image-classification-on-cifar-100)
# - [pytorch-basic-cifar10](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)
# - [more-implementation-with-explanations](https://blog.jovian.ai/image-classification-of-cifar100-dataset-using-pytorch-8b7145242df1)
# - [more-reading](https://www.researchgate.net/publication/355698607_MEST_Accurate_and_Fast_Memory-Economic_Sparse_Training_Framework_on_the_Edge)
# - [visualization](https://jovian.ai/damian-c036/cifar100-final-project/v/5?utm_source=embed)
#
#
# So we are good to go.

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import CIFAR100
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split, ConcatDataset
import torchvision.transforms as tt

from adabelief_pytorch import AdaBelief

# %% [markdown]
# ____
# #### Before we load the data, it is required to first prepare the transformations to be applied. It is an important step to prepare the data for training to avoid overfitting problem.
# ____

# %%
stats = ((0.5074,0.4867,0.4411),(0.2011,0.1987,0.2025))
train_transform = tt.Compose([
    tt.RandomHorizontalFlip(),
    tt.RandomCrop(32, padding=4, padding_mode="reflect"),
    tt.ToTensor(),
    tt.Normalize(*stats)
])

test_transform = tt.Compose([
    tt.ToTensor(),
    tt.Normalize(*stats)
])

# %% [markdown]
# ___
# RandomHorizontalFlip randomly flips an image with a probability of 50%, and RandomCrop pads an image by 4 pixel on each side then randomly crops 32x32 from the image after padding. We add such transformations to add noise to the data and prevent our model from overfitting. There are also other transformations you can use such as ColorJitter and RandomVerticalFlip etc. but I found these to be sufficient for our purposes. <br />
#
# ToTensor simply converts the image to a Tensor. Since its a coloured image, it would have 3 channels (R,G,B) so the Tensor would be of size 3x32x32. <br/>
#
# Normalize takes the mean and standard deviation for each channel of the entire dataset as input. Normalizing scales our data to a similar range of values to make sure that our gradients don’t go out of control.
# Now we just prepare our train and test dataset and then we can explore the data.
# ___

# %% [markdown]
# # Loading Data

# %%
train_data = CIFAR100(download=True, root="./data", transform=train_transform)
test_data = CIFAR100(root="./data", train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# _____

# %%
for image, label in train_data:
    print("Image shape: ",image.shape)
    print("Image tensor: ", image)
    print("Label: ", label)
    break
# Out:
# Image shape:  torch.Size([3, 32, 32])
# Image tensor:  tensor([[[ 1.3380,  0.7920,  0.6165,  ...,  2.4300,  2.4300,  2.4300],
#          [ 1.2405,  1.1625,  0.7140,  ...,  2.4495,  2.4495,  2.4495],
#          [ 1.2210,  0.7335,  0.3825,  ...,  2.4495,  2.4495,  2.4495],
#          ...,
#          [-1.9381, -2.0941, -0.6316,  ..., -0.6316, -0.7096, -0.5926],
#          [-2.1526, -1.8601, -0.4756,  ..., -0.3001, -1.1191, -0.8656],
#          [-1.9381, -2.0941, -0.6316,  ..., -0.6316, -0.7096, -0.5926]],
#
#         [[ 1.7149,  1.0241,  0.8662,  ...,  2.5636,  2.5636,  2.5636],
#          [ 1.6557,  1.4781,  1.0636,  ...,  2.5833,  2.5833,  2.5833],
#          [ 1.5767,  1.1228,  0.7478,  ...,  2.5833,  2.5833,  2.5833],
#          ...,
#          [-2.0547, -2.1336, -0.2390,  ...,  0.1755,  0.0965,  0.2150],
#          [-2.2718, -1.7389,  0.1755,  ...,  0.4715, -0.3969, -0.1403],
#          [-2.0547, -2.1336, -0.2390,  ...,  0.1755,  0.0965,  0.2150]],
#
#         [[ 1.5787,  0.7266,  0.3393,  ...,  2.7406,  2.7406,  2.7406],
#          [ 1.4044,  1.0945,  0.3393,  ...,  2.7600,  2.7600,  2.7600],
#          [ 1.1526,  0.4361, -0.0480,  ...,  2.7600,  2.7600,  2.7600],
#          ...,
#          [-2.1395, -2.1202, -1.0938,  ..., -1.3068, -1.4811, -1.3843],
#          [-2.1008, -1.9846, -1.0357,  ..., -0.9776, -1.5973, -1.3455],
#          [-2.1395, -2.1202, -1.0938,  ..., -1.3068, -1.4811, -1.3843]]])
# Label:  19

# %%
train_classes_items = dict()

for train_item in train_data:
    label = train_data.classes[train_item[1]]
    if label not in train_classes_items:
        train_classes_items[label] = 1
    else:
        train_classes_items[label] += 1

train_classes_items
# Out:
# {'cattle': 500,
#  'dinosaur': 500,
#  'apple': 500,
#  'boy': 500,
#  'aquarium_fish': 500,
#  'telephone': 500,
#  'train': 500,
#  'cup': 500,
#  'cloud': 500,
#  'elephant': 500,
#  'keyboard': 500,
#  'willow_tree': 500,
#  'sunflower': 500,
#  'castle': 500,
#  'sea': 500,
#  'bicycle': 500,
#  'wolf': 500,
#  'squirrel': 500,
#  'shrew': 500,
#  'pine_tree': 500,
#  'rose': 500,
#  'television': 500,
#  'table': 500,
#  'possum': 500,
#  'oak_tree': 500,
#  'leopard': 500,
#  'maple_tree': 500,
#  'rabbit': 500,
#  'chimpanzee': 500,
#  'clock': 500,
#  'streetcar': 500,
#  'cockroach': 500,
#  'snake': 500,
#  'lobster': 500,
#  'mountain': 500,
#  'palm_tree': 500,
#  'skyscraper': 500,
#  'tractor': 500,
#  'shark': 500,
#  'butterfly': 500,
#  'bottle': 500,
#  'bee': 500,
#  'chair': 500,
#  'woman': 500,
#  'hamster': 500,
#  'otter': 500,
#  'seal': 500,
#  'lion': 500,
#  'mushroom': 500,
#  'girl': 500,
#  'sweet_pepper': 500,
#  'forest': 500,
#  'crocodile': 500,
#  'orange': 500,
#  'tulip': 500,
#  'mouse': 500,
#  'camel': 500,
#  'caterpillar': 500,
#  'man': 500,
#  'skunk': 500,
#  'kangaroo': 500,
#  'raccoon': 500,
#  'snail': 500,
#  'rocket': 500,
#  'whale': 500,
#  'worm': 500,
#  'turtle': 500,
#  'beaver': 500,
#  'plate': 500,
#  'wardrobe': 500,
#  'road': 500,
#  'fox': 500,
#  'flatfish': 500,
#  'tiger': 500,
#  'ray': 500,
#  'dolphin': 500,
#  'poppy': 500,
#  'porcupine': 500,
#  'lamp': 500,
#  'crab': 500,
#  'motorcycle': 500,
#  'spider': 500,
#  'tank': 500,
#  'orchid': 500,
#  'lizard': 500,
#  'beetle': 500,
#  'bridge': 500,
#  'baby': 500,
#  'lawn_mower': 500,
#  'house': 500,
#  'bus': 500,
#  'couch': 500,
#  'bowl': 500,
#  'pear': 500,
#  'bed': 500,
#  'plain': 500,
#  'trout': 500,
#  'bear': 500,
#  'pickup_truck': 500,
#  'can': 500}

# %%
test_classes_items = dict()
for test_item in test_data:
    label = test_data.classes[test_item[1]]
    if label not in test_classes_items:
        test_classes_items[label] = 1
    else:
        test_classes_items[label] += 1

test_classes_items
# Out:
# {'mountain': 100,
#  'forest': 100,
#  'seal': 100,
#  'mushroom': 100,
#  'sea': 100,
#  'tulip': 100,
#  'camel': 100,
#  'butterfly': 100,
#  'cloud': 100,
#  'apple': 100,
#  'skunk': 100,
#  'streetcar': 100,
#  'rocket': 100,
#  'lamp': 100,
#  'lion': 100,
#  'wolf': 100,
#  'rose': 100,
#  'orange': 100,
#  'dinosaur': 100,
#  'chimpanzee': 100,
#  'can': 100,
#  'keyboard': 100,
#  'bicycle': 100,
#  'chair': 100,
#  'plate': 100,
#  'lawn_mower': 100,
#  'turtle': 100,
#  'palm_tree': 100,
#  'shark': 100,
#  'pickup_truck': 100,
#  'boy': 100,
#  'couch': 100,
#  'house': 100,
#  'porcupine': 100,
#  'cockroach': 100,
#  'clock': 100,
#  'castle': 100,
#  'beaver': 100,
#  'bee': 100,
#  'bottle': 100,
#  'pear': 100,
#  'baby': 100,
#  'flatfish': 100,
#  'oak_tree': 100,
#  'leopard': 100,
#  'snail': 100,
#  'crocodile': 100,
#  'rabbit': 100,
#  'beetle': 100,
#  'girl': 100,
#  'sunflower': 100,
#  'raccoon': 100,
#  'train': 100,
#  'ray': 100,
#  'trout': 100,
#  'bowl': 100,
#  'snake': 100,
#  'orchid': 100,
#  'tractor': 100,
#  'caterpillar': 100,
#  'bus': 100,
#  'mouse': 100,
#  'crab': 100,
#  'sweet_pepper': 100,
#  'maple_tree': 100,
#  'whale': 100,
#  'skyscraper': 100,
#  'pine_tree': 100,
#  'tank': 100,
#  'cattle': 100,
#  'man': 100,
#  'aquarium_fish': 100,
#  'shrew': 100,
#  'plain': 100,
#  'possum': 100,
#  'lobster': 100,
#  'hamster': 100,
#  'television': 100,
#  'dolphin': 100,
#  'worm': 100,
#  'squirrel': 100,
#  'cup': 100,
#  'woman': 100,
#  'bridge': 100,
#  'wardrobe': 100,
#  'road': 100,
#  'lizard': 100,
#  'elephant': 100,
#  'spider': 100,
#  'fox': 100,
#  'otter': 100,
#  'poppy': 100,
#  'willow_tree': 100,
#  'table': 100,
#  'kangaroo': 100,
#  'telephone': 100,
#  'bed': 100,
#  'motorcycle': 100,
#  'bear': 100,
#  'tiger': 100}

# %% [markdown]
# # BATCHSIZE & DataLoader

# %%
BATCH_SIZE = 128
train_dl = DataLoader(train_data, BATCH_SIZE, num_workers=4, pin_memory=True, shuffle=True)
test_dl = DataLoader(test_data, BATCH_SIZE, num_workers=4, pin_memory=True)

# %% [markdown]
# # Visualization

# %%
# for 8 images
train_8_samples = DataLoader(train_data, 8, num_workers=4, pin_memory=True, shuffle=True)

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize = (20,20))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(train_8_samples)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print(''.join(f'{train_data.classes[labels[j]]:20s}' for j in range(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# shark               plate               palm_tree           leopard             aquarium_fish       snake               poppy               snake

# %% [markdown]
# # Get CUDA ready

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    return torch.device("cpu")

def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device) for x in data]
    return data.to(device,non_blocking=True)


class ToDeviceLoader:
    def __init__(self,data,device):
        self.data = data
        self.device = device
        
    def __iter__(self):
        for batch in self.data:
            yield to_device(batch,self.device)
            
    def __len__(self):
        return len(self.data)

# %%
device = get_device()
print(device)

train_dl = ToDeviceLoader(train_dl, device)
test_dl = ToDeviceLoader(test_dl, device)
# Out:
# cuda

# %%
def accuracy(predicted, actual):
    _, predictions = torch.max(predicted, dim=1)
    return torch.tensor(torch.sum(predictions==actual).item()/len(predictions))

# %% [markdown]
# # BaseModel

# %%
class BaseModel(nn.Module):
    def training_step(self,batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        return loss
    
    def validation_step(self,batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {"val_loss":loss.detach(),"val_acc":acc}
    
    def validation_epoch_end(self,outputs):
        batch_losses = [loss["val_loss"] for loss in outputs]
        loss = torch.stack(batch_losses).mean()
        batch_accuracy = [accuracy["val_acc"] for accuracy in outputs]
        acc = torch.stack(batch_accuracy).mean()
        return {"val_loss":loss.item(),"val_acc":acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# # ResNet Implementation
#
# BaseModel allows us to check and record the results of our model every time we train and pretty much just helps us keep track of our progress. This is what our actual model will inherit. <br />
#
# I implemented ResNet with changing a little bit that worked better than the one I got and used as base.<br />
#
# #### An example figure of ResNet approach to understand easily what we will see below as code:
#
# ![image.png](attachment:5e638e86-7b48-499f-847d-741d69568111.png)
# <br/><br/><br/><br/>
# ____

# %%
# def conv_shortcut(in_channel, out_channel, stride):
#     layers = [nn.Conv2d(in_channel, out_channel, kernel_size=(1,1), stride=(stride, stride)),
#              nn.BatchNorm2d(out_channel)]
#     return nn.Sequential(*layers)

# def block(in_channel, out_channel, k_size,stride, conv=False):
#     layers = None
    
#     first_layers = [nn.Conv2d(in_channel,out_channel[0], kernel_size=(1,1),stride=(1,1)),
#                     nn.BatchNorm2d(out_channel[0]),
#                     nn.ReLU(inplace=True)]
#     if conv:
#         first_layers[0].stride=(stride,stride)
    
#     second_layers = [nn.Conv2d(out_channel[0], out_channel[1], kernel_size=(k_size, k_size), stride=(1,1), padding=1),
#                     nn.BatchNorm2d(out_channel[1])]

#     layers = first_layers + second_layers
    
#     return nn.Sequential(*layers)
    

# class ResNet(BaseModel):
    
#     def __init__(self, in_channels, num_classes):
#         super().__init__()
        
#         self.stg1 = nn.Sequential(
#                                    nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=(3),
#                                              stride=(1), padding=1),
#                                    nn.BatchNorm2d(64),
#                                    nn.ReLU(inplace=True),
#                                    nn.MaxPool2d(kernel_size=3, stride=2))
        
#         ##stage 2
#         self.convShortcut2 = conv_shortcut(64,256,1)
        
#         self.conv2 = block(64,[64,256],3,1,conv=True)
#         self.ident2 = block(256,[64,256],3,1)

        
#         ##stage 3
#         self.convShortcut3 = conv_shortcut(256,512,2)
        
#         self.conv3 = block(256,[128,512],3,2,conv=True)
#         self.ident3 = block(512,[128,512],3,2)

        
#         ##stage 4
#         self.convShortcut4 = conv_shortcut(512,1024,2)
        
#         self.conv4 = block(512,[256,1024],3,2,conv=True)
#         self.ident4 = block(1024,[256,1024],3,2)
        
        
#         ##Classify
#         self.classifier = nn.Sequential(
#                                        nn.AvgPool2d(kernel_size=(4)),
#                                        nn.Flatten(),
#                                        nn.Linear(1024, num_classes))
        
#     def forward(self,inputs):
#         out = self.stg1(inputs)
        
#         #stage 2
#         out = F.relu(self.conv2(out) + self.convShortcut2(out))
#         out = F.relu(self.ident2(out) + out)
#         out = F.relu(self.ident2(out) + out)
#         out = F.relu(self.ident2(out) + out)
        
#         #stage3
#         out = F.relu(self.conv3(out) + (self.convShortcut3(out)))
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
        
#         #stage4             
#         out = F.relu(self.conv4(out) + (self.convShortcut4(out)))
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
        
#         #Classify
#         out = self.classifier(out)#100x1024
        
#         return out

# %%
# model = ResNet(3,100)
from torchvision import models

class ResNet101Model(BaseModel):
    def __init__(self, num_classes):
        super().__init__()
        self.model = models.resnet101(pretrained=False)
        num_ftrs = self.model.fc.in_features
        self.model.fc = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
model = ResNet101Model(num_classes=100)
model = to_device(model, device)
# Out:
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# # Evaluation & Fit Function for Training

# %%
@torch.no_grad()
def evaluate(model,test_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in test_dl]
    return model.validation_epoch_end(outputs)

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit (epochs, train_dl, test_dl, model, optimizer, max_lr, weight_decay, scheduler, grad_clip=None):
    torch.cuda.empty_cache()
    
    history = []
    
    optimizer = optimizer(model.parameters(), max_lr, weight_decay = weight_decay)
    
    scheduler = scheduler(optimizer, T_max=epochs * len(train_dl))
    
    for epoch in range(epochs):
        model.train()
        
        train_loss = []
        
        lrs = []
        
        for batch in train_dl:
            loss = model.training_step(batch)
            
            train_loss.append(loss)
            
            loss.backward()
            
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            scheduler.step()
            lrs.append(get_lr(optimizer))
        result = evaluate(model, test_dl)
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["lrs"] = lrs
        
        model.epoch_end(epoch,result)
        history.append(result)
        
    return history

# %% [markdown]
# # Hyperparameters
#
# - **max_lr**: is the maximum learning rate that we set for learning rate scheduler. For the learning rate scheduler we used OneCycleLR, which sets the learning rate to a low learning rate, gradually increases it to the max learning rate then goes back to a low learning rate. <br/>
# - **grad_clip**: prevents the gradients to become too large. <br/>
# - **weight_decay**: essentially tries to make the model simple and helps the model generalise better.

# %%
epochs = 200
optimizer = AdaBelief
max_lr = 0.01
grad_clip = 0.1
weight_decay = 5e-3
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR

# %% [markdown]
# # Training

# %%
# %%time
history = fit(epochs=epochs, train_dl=train_dl, test_dl=test_dl, model=model, 
              optimizer=optimizer, max_lr=max_lr,
              weight_decay=weight_decay, scheduler=scheduler)
# Out:
# Please check your arguments if you have upgraded adabelief-pytorch from version 0.0.5.
# Modifications to default arguments:
#                            eps  weight_decouple    rectify
# -----------------------  -----  -----------------  ---------
# adabelief-pytorch=0.0.5  1e-08  False              False
# >=0.1.0 (Current 0.2.0)  1e-16  True               True
# SGD better than Adam (e.g. CNN for Image Classification)    Adam better than SGD (e.g. Transformer, GAN)
# ----------------------------------------------------------  ----------------------------------------------
# Recommended eps = 1e-8                                      Recommended eps = 1e-16
# For a complete table of recommended hyperparameters, see
# https://github.com/juntang-zhuang/Adabelief-Optimizer
# You can disable the log message by setting "print_change_log = False", though it is recommended to keep as a reminder.
#
# Weight decoupling enabled in AdaBelief
# Rectification enabled in AdaBelief
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [0], last_lr: 0.01000, train_loss: 4.8214, val_loss: 6.9202, val_acc: 0.0482
# Epoch [1], last_lr: 0.01000, train_loss: 4.1939, val_loss: 5.1936, val_acc: 0.0315
# Epoch [2], last_lr: 0.00999, train_loss: 3.8302, val_loss: 3.6561, val_acc: 0.1319
# Epoch [3], last_lr: 0.00999, train_loss: 3.5455, val_loss: 3.4443, val_acc: 0.1653
# Epoch [4], last_lr: 0.00998, train_loss: 3.4107, val_loss: 3.3539, val_acc: 0.1841
# Epoch [5], last_lr: 0.00998, train_loss: 3.3113, val_loss: 3.4116, val_acc: 0.1764
# Epoch [6], last_lr: 0.00997, train_loss: 3.3572, val_loss: 3.3385, val_acc: 0.1962
# Epoch [7], last_lr: 0.00996, train_loss: 3.2363, val_loss: 3.2454, val_acc: 0.2186
# Epoch [8], last_lr: 0.00995, train_loss: 3.0956, val_loss: 3.0322, val_acc: 0.2559
# Epoch [9], last_lr: 0.00994, train_loss: 3.0395, val_loss: 3.0059, val_acc: 0.2627
# Epoch [10], last_lr: 0.00993, train_loss: 3.0564, val_loss: 2.9261, val_acc: 0.2695
# Epoch [11], last_lr: 0.00991, train_loss: 2.9051, val_loss: 2.8612, val_acc: 0.2862
# Epoch [12], last_lr: 0.00990, train_loss: 2.7908, val_loss: 2.8023, val_acc: 0.2889
# Epoch [13], last_lr: 0.00988, train_loss: 2.7661, val_loss: 2.9258, val_acc: 0.2711
# Epoch [14], last_lr: 0.00986, train_loss: 3.2279, val_loss: 3.1438, val_acc: 0.2545
# Epoch [15], last_lr: 0.00984, train_loss: 3.3242, val_loss: 3.5493, val_acc: 0.1837
# Epoch [16], last_lr: 0.00982, train_loss: 3.2751, val_loss: 3.2316, val_acc: 0.2148
# Epoch [17], last_lr: 0.00980, train_loss: 3.2615, val_loss: 3.2135, val_acc: 0.2178
# Epoch [18], last_lr: 0.00978, train_loss: 3.0251, val_loss: 2.8778, val_acc: 0.2780
# Epoch [19], last_lr: 0.00976, train_loss: 2.8588, val_loss: 2.9310, val_acc: 0.3068
# Epoch [20], last_lr: 0.00973, train_loss: 2.9745, val_loss: 2.9260, val_acc: 0.2764
# Epoch [21], last_lr: 0.00970, train_loss: 2.9077, val_loss: 2.8878, val_acc: 0.2808
# Epoch [22], last_lr: 0.00968, train_loss: 2.8190, val_loss: 2.7478, val_acc: 0.3086
# Epoch [23], last_lr: 0.00965, train_loss: 2.8700, val_loss: 2.7772, val_acc: 0.3106
# Epoch [24], last_lr: 0.00962, train_loss: 2.7549, val_loss: 3.2470, val_acc: 0.2326
# Epoch [25], last_lr: 0.00959, train_loss: 3.1122, val_loss: 2.8802, val_acc: 0.2897
# Epoch [26], last_lr: 0.00956, train_loss: 2.7062, val_loss: 2.7183, val_acc: 0.3254
# Epoch [27], last_lr: 0.00952, train_loss: 2.6000, val_loss: 2.6926, val_acc: 0.3216
# Epoch [28], last_lr: 0.00949, train_loss: 2.7240, val_loss: 3.1306, val_acc: 0.2530
# Epoch [29], last_lr: 0.00946, train_loss: 2.8224, val_loss: 2.5855, val_acc: 0.3431
# Epoch [30], last_lr: 0.00942, train_loss: 2.5572, val_loss: 2.7356, val_acc: 0.3134
# Epoch [31], last_lr: 0.00938, train_loss: 2.5630, val_loss: 2.6329, val_acc: 0.3588
# Epoch [32], last_lr: 0.00934, train_loss: 2.4589, val_loss: 2.4849, val_acc: 0.3758
# Epoch [33], last_lr: 0.00930, train_loss: 2.4002, val_loss: 2.4147, val_acc: 0.3875
# Epoch [34], last_lr: 0.00926, train_loss: 2.3621, val_loss: 2.4901, val_acc: 0.3800
# Epoch [35], last_lr: 0.00922, train_loss: 2.4279, val_loss: 2.9589, val_acc: 0.3867
# Epoch [36], last_lr: 0.00918, train_loss: 2.2857, val_loss: 2.3716, val_acc: 0.3834
# Epoch [37], last_lr: 0.00914, train_loss: 2.2591, val_loss: 2.4606, val_acc: 0.4019
# Epoch [38], last_lr: 0.00909, train_loss: 2.4020, val_loss: 2.5996, val_acc: 0.3482
# Epoch [39], last_lr: 0.00905, train_loss: 2.4795, val_loss: 2.5627, val_acc: 0.3619
# Epoch [40], last_lr: 0.00900, train_loss: 2.4730, val_loss: 2.5534, val_acc: 0.3525
# Epoch [41], last_lr: 0.00895, train_loss: 2.6254, val_loss: 3.0043, val_acc: 0.3192
# Epoch [42], last_lr: 0.00890, train_loss: 2.6004, val_loss: 2.4405, val_acc: 0.3768
# Epoch [43], last_lr: 0.00885, train_loss: 2.5925, val_loss: 3.8355, val_acc: 0.3762
# Epoch [44], last_lr: 0.00880, train_loss: 2.6679, val_loss: 2.5258, val_acc: 0.3625
# Epoch [45], last_lr: 0.00875, train_loss: 2.3640, val_loss: 2.4068, val_acc: 0.3920
# Epoch [46], last_lr: 0.00870, train_loss: 2.4199, val_loss: 2.4814, val_acc: 0.3897
# Epoch [47], last_lr: 0.00864, train_loss: 2.2937, val_loss: 2.4790, val_acc: 0.4048
# Epoch [48], last_lr: 0.00859, train_loss: 2.1639, val_loss: 2.3370, val_acc: 0.4110
# Epoch [49], last_lr: 0.00854, train_loss: 2.1313, val_loss: 2.3594, val_acc: 0.4218
# Epoch [50], last_lr: 0.00848, train_loss: 2.1894, val_loss: 2.7130, val_acc: 0.4167
# Epoch [51], last_lr: 0.00842, train_loss: 2.0623, val_loss: 3.1540, val_acc: 0.4170
# Epoch [52], last_lr: 0.00837, train_loss: 2.2234, val_loss: 4.3750, val_acc: 0.4092
# Epoch [53], last_lr: 0.00831, train_loss: 2.2513, val_loss: 2.5038, val_acc: 0.4195
# Epoch [54], last_lr: 0.00825, train_loss: 2.2828, val_loss: 2.6692, val_acc: 0.4051
# Epoch [55], last_lr: 0.00819, train_loss: 2.2255, val_loss: 2.3651, val_acc: 0.3952
# Epoch [56], last_lr: 0.00813, train_loss: 2.1155, val_loss: 5.9664, val_acc: 0.4203
# Epoch [57], last_lr: 0.00806, train_loss: 2.1687, val_loss: 2.3011, val_acc: 0.4239
# Epoch [58], last_lr: 0.00800, train_loss: 2.0321, val_loss: 4.4990, val_acc: 0.3219
# Epoch [59], last_lr: 0.00794, train_loss: 2.0765, val_loss: 2.4388, val_acc: 0.4458
# Epoch [60], last_lr: 0.00788, train_loss: 2.0505, val_loss: 2.4048, val_acc: 0.4460
# Epoch [61], last_lr: 0.00781, train_loss: 2.5128, val_loss: 3.6661, val_acc: 0.2663
# Epoch [62], last_lr: 0.00775, train_loss: 2.2335, val_loss: 2.2012, val_acc: 0.4351
# Epoch [63], last_lr: 0.00768, train_loss: 2.0410, val_loss: 2.4152, val_acc: 0.4112
# Epoch [64], last_lr: 0.00761, train_loss: 2.0139, val_loss: 2.3083, val_acc: 0.4453
# Epoch [65], last_lr: 0.00755, train_loss: 1.9007, val_loss: 2.1262, val_acc: 0.4565
# Epoch [66], last_lr: 0.00748, train_loss: 2.0309, val_loss: 2.3495, val_acc: 0.4106
# Epoch [67], last_lr: 0.00741, train_loss: 1.9469, val_loss: 3.1364, val_acc: 0.4329
# Epoch [68], last_lr: 0.00734, train_loss: 1.8628, val_loss: 2.4605, val_acc: 0.3931
# Epoch [69], last_lr: 0.00727, train_loss: 2.1033, val_loss: 3.2950, val_acc: 0.2868
# Epoch [70], last_lr: 0.00720, train_loss: 2.0885, val_loss: 2.1404, val_acc: 0.4547
# Epoch [71], last_lr: 0.00713, train_loss: 2.0078, val_loss: 2.9352, val_acc: 0.4480
# Epoch [72], last_lr: 0.00706, train_loss: 2.0326, val_loss: 2.9034, val_acc: 0.4204
# Epoch [73], last_lr: 0.00699, train_loss: 1.8652, val_loss: 2.9696, val_acc: 0.3515
# Epoch [74], last_lr: 0.00691, train_loss: 1.9866, val_loss: 3.3167, val_acc: 0.3917
# Epoch [75], last_lr: 0.00684, train_loss: 2.0915, val_loss: 3.0450, val_acc: 0.4333
# Epoch [76], last_lr: 0.00677, train_loss: 1.9136, val_loss: 4.5224, val_acc: 0.4470
# Epoch [77], last_lr: 0.00669, train_loss: 1.8853, val_loss: 2.9202, val_acc: 0.4553
# Epoch [78], last_lr: 0.00662, train_loss: 1.9918, val_loss: 4.3972, val_acc: 0.4352
# Epoch [79], last_lr: 0.00655, train_loss: 2.1037, val_loss: 2.8305, val_acc: 0.3993
# Epoch [80], last_lr: 0.00647, train_loss: 1.9431, val_loss: 2.2271, val_acc: 0.4367
# Epoch [81], last_lr: 0.00639, train_loss: 1.9521, val_loss: 2.7842, val_acc: 0.3667
# Epoch [82], last_lr: 0.00632, train_loss: 1.9617, val_loss: 2.4811, val_acc: 0.4578
# Epoch [83], last_lr: 0.00624, train_loss: 1.8680, val_loss: 3.0910, val_acc: 0.4396
# Epoch [84], last_lr: 0.00617, train_loss: 1.7417, val_loss: 2.5894, val_acc: 0.4593
# Epoch [85], last_lr: 0.00609, train_loss: 1.7544, val_loss: 2.4371, val_acc: 0.4710
# Epoch [86], last_lr: 0.00601, train_loss: 1.8404, val_loss: 2.4046, val_acc: 0.4618
# Epoch [87], last_lr: 0.00594, train_loss: 1.7539, val_loss: 2.3255, val_acc: 0.4671
# Epoch [88], last_lr: 0.00586, train_loss: 1.7447, val_loss: 3.0020, val_acc: 0.4631
# Epoch [89], last_lr: 0.00578, train_loss: 1.6199, val_loss: 2.2106, val_acc: 0.4755
# Epoch [90], last_lr: 0.00570, train_loss: 1.7698, val_loss: 2.9239, val_acc: 0.4479
# Epoch [91], last_lr: 0.00563, train_loss: 1.7349, val_loss: 2.6176, val_acc: 0.4163
# Epoch [92], last_lr: 0.00555, train_loss: 1.6724, val_loss: 3.4135, val_acc: 0.4585
# Epoch [93], last_lr: 0.00547, train_loss: 1.6581, val_loss: 2.3910, val_acc: 0.4177
# Epoch [94], last_lr: 0.00539, train_loss: 1.6176, val_loss: 2.2266, val_acc: 0.4643
# Epoch [95], last_lr: 0.00531, train_loss: 1.7596, val_loss: 5.0162, val_acc: 0.3032
# Epoch [96], last_lr: 0.00524, train_loss: 1.6978, val_loss: 2.8522, val_acc: 0.4732
# Epoch [97], last_lr: 0.00516, train_loss: 1.5937, val_loss: 2.5760, val_acc: 0.4792
# Epoch [98], last_lr: 0.00508, train_loss: 1.5906, val_loss: 2.3652, val_acc: 0.4885
# Epoch [99], last_lr: 0.00500, train_loss: 1.7081, val_loss: 5.7848, val_acc: 0.4615
# Epoch [100], last_lr: 0.00492, train_loss: 1.7882, val_loss: 3.5784, val_acc: 0.3652
# Epoch [101], last_lr: 0.00484, train_loss: 1.9297, val_loss: 2.6171, val_acc: 0.4388
# Epoch [102], last_lr: 0.00476, train_loss: 1.7785, val_loss: 3.6715, val_acc: 0.4579
# Epoch [103], last_lr: 0.00469, train_loss: 1.6566, val_loss: 2.6561, val_acc: 0.4597
# Epoch [104], last_lr: 0.00461, train_loss: 1.5532, val_loss: 3.0590, val_acc: 0.4800
# Epoch [105], last_lr: 0.00453, train_loss: 1.5796, val_loss: 2.9565, val_acc: 0.4443
# Epoch [106], last_lr: 0.00445, train_loss: 1.5255, val_loss: 2.7630, val_acc: 0.4653
# Epoch [107], last_lr: 0.00437, train_loss: 1.5007, val_loss: 2.6228, val_acc: 0.4776
# Epoch [108], last_lr: 0.00430, train_loss: 1.4570, val_loss: 2.8438, val_acc: 0.4757
# Epoch [109], last_lr: 0.00422, train_loss: 1.5643, val_loss: 3.7688, val_acc: 0.4821
# Epoch [110], last_lr: 0.00414, train_loss: 1.5146, val_loss: 2.3185, val_acc: 0.4556
# Epoch [111], last_lr: 0.00406, train_loss: 1.5624, val_loss: 2.8659, val_acc: 0.4799
# Epoch [112], last_lr: 0.00399, train_loss: 1.5835, val_loss: 3.6937, val_acc: 0.4674
# Epoch [113], last_lr: 0.00391, train_loss: 1.6874, val_loss: 3.0755, val_acc: 0.4376
# Epoch [114], last_lr: 0.00383, train_loss: 1.6180, val_loss: 2.3578, val_acc: 0.4646
# Epoch [115], last_lr: 0.00376, train_loss: 1.5190, val_loss: 3.3275, val_acc: 0.4605
# Epoch [116], last_lr: 0.00368, train_loss: 1.4871, val_loss: 4.5861, val_acc: 0.4703
# Epoch [117], last_lr: 0.00361, train_loss: 1.4641, val_loss: 2.6297, val_acc: 0.4796
# Epoch [118], last_lr: 0.00353, train_loss: 1.5309, val_loss: 4.2897, val_acc: 0.4706
# Epoch [119], last_lr: 0.00345, train_loss: 1.4009, val_loss: 2.7648, val_acc: 0.4871
# Epoch [120], last_lr: 0.00338, train_loss: 1.3558, val_loss: 3.1436, val_acc: 0.4871
# Epoch [121], last_lr: 0.00331, train_loss: 1.5499, val_loss: 2.6803, val_acc: 0.4592
# Epoch [122], last_lr: 0.00323, train_loss: 1.5859, val_loss: 3.5626, val_acc: 0.4576
# Epoch [123], last_lr: 0.00316, train_loss: 1.5762, val_loss: 2.6679, val_acc: 0.4773
# Epoch [124], last_lr: 0.00309, train_loss: 1.6552, val_loss: 3.1040, val_acc: 0.3980
# Epoch [125], last_lr: 0.00301, train_loss: 1.5975, val_loss: 2.8689, val_acc: 0.4697
# Epoch [126], last_lr: 0.00294, train_loss: 1.3588, val_loss: 2.9290, val_acc: 0.4798
# Epoch [127], last_lr: 0.00287, train_loss: 1.7919, val_loss: 7.2197, val_acc: 0.4628
# Epoch [128], last_lr: 0.00280, train_loss: 1.4787, val_loss: 33.1456, val_acc: 0.4220
# Epoch [129], last_lr: 0.00273, train_loss: 1.4820, val_loss: 2.1073, val_acc: 0.4779
# Epoch [130], last_lr: 0.00266, train_loss: 1.3597, val_loss: 2.1131, val_acc: 0.4878
# Epoch [131], last_lr: 0.00259, train_loss: 1.2509, val_loss: 2.1045, val_acc: 0.4862
# Epoch [132], last_lr: 0.00252, train_loss: 1.2143, val_loss: 2.0912, val_acc: 0.4972
# Epoch [133], last_lr: 0.00245, train_loss: 1.1473, val_loss: 2.1216, val_acc: 0.4936
# Epoch [134], last_lr: 0.00239, train_loss: 1.1308, val_loss: 2.1058, val_acc: 0.4875
# Epoch [135], last_lr: 0.00232, train_loss: 1.1084, val_loss: 2.1546, val_acc: 0.4875
# Epoch [136], last_lr: 0.00225, train_loss: 1.0846, val_loss: 2.2434, val_acc: 0.4771
# Epoch [137], last_lr: 0.00219, train_loss: 1.0576, val_loss: 2.2140, val_acc: 0.4899
# Epoch [138], last_lr: 0.00212, train_loss: 1.0392, val_loss: 2.1898, val_acc: 0.4907
# Epoch [139], last_lr: 0.00206, train_loss: 1.0276, val_loss: 2.2527, val_acc: 0.4877
# Epoch [140], last_lr: 0.00200, train_loss: 0.9973, val_loss: 2.2388, val_acc: 0.4970
# Epoch [141], last_lr: 0.00194, train_loss: 1.0500, val_loss: 2.2224, val_acc: 0.4892
# Epoch [142], last_lr: 0.00187, train_loss: 0.9555, val_loss: 2.3120, val_acc: 0.4901
# Epoch [143], last_lr: 0.00181, train_loss: 0.9733, val_loss: 2.2221, val_acc: 0.4943
# Epoch [144], last_lr: 0.00175, train_loss: 0.9785, val_loss: 2.3199, val_acc: 0.4809
# Epoch [145], last_lr: 0.00169, train_loss: 0.9443, val_loss: 2.2641, val_acc: 0.4953
# Epoch [146], last_lr: 0.00163, train_loss: 0.8849, val_loss: 2.2892, val_acc: 0.4933
# Epoch [147], last_lr: 0.00158, train_loss: 0.8591, val_loss: 2.3170, val_acc: 0.4975
# Epoch [148], last_lr: 0.00152, train_loss: 0.8442, val_loss: 2.2965, val_acc: 0.4967
# Epoch [149], last_lr: 0.00146, train_loss: 0.8191, val_loss: 2.3669, val_acc: 0.4965
# Epoch [150], last_lr: 0.00141, train_loss: 0.8075, val_loss: 2.3888, val_acc: 0.4965
# Epoch [151], last_lr: 0.00136, train_loss: 0.7897, val_loss: 2.4626, val_acc: 0.4948
# Epoch [152], last_lr: 0.00130, train_loss: 0.7693, val_loss: 2.5153, val_acc: 0.4940
# Epoch [153], last_lr: 0.00125, train_loss: 0.7520, val_loss: 2.5197, val_acc: 0.4953
# Epoch [154], last_lr: 0.00120, train_loss: 0.7378, val_loss: 2.4996, val_acc: 0.4954
# Epoch [155], last_lr: 0.00115, train_loss: 0.7359, val_loss: 2.5678, val_acc: 0.4904
# Epoch [156], last_lr: 0.00110, train_loss: 0.7144, val_loss: 2.5485, val_acc: 0.4964
# Epoch [157], last_lr: 0.00105, train_loss: 0.7320, val_loss: 2.5059, val_acc: 0.4943
# Epoch [158], last_lr: 0.00100, train_loss: 0.7021, val_loss: 2.4300, val_acc: 0.4996
# Epoch [159], last_lr: 0.00095, train_loss: 0.6701, val_loss: 2.8190, val_acc: 0.4966
# Epoch [160], last_lr: 0.00091, train_loss: 0.6447, val_loss: 2.4875, val_acc: 0.5055
# Epoch [161], last_lr: 0.00086, train_loss: 0.6271, val_loss: 2.5354, val_acc: 0.5039
# Epoch [162], last_lr: 0.00082, train_loss: 0.6303, val_loss: 2.5897, val_acc: 0.4974
# Epoch [163], last_lr: 0.00078, train_loss: 0.6119, val_loss: 2.5252, val_acc: 0.4980
# Epoch [164], last_lr: 0.00074, train_loss: 0.6003, val_loss: 2.5698, val_acc: 0.5024
# Epoch [165], last_lr: 0.00070, train_loss: 0.5875, val_loss: 2.6975, val_acc: 0.5004
# Epoch [166], last_lr: 0.00066, train_loss: 0.5938, val_loss: 2.6881, val_acc: 0.4986
# Epoch [167], last_lr: 0.00062, train_loss: 0.5773, val_loss: 2.7350, val_acc: 0.4953
# Epoch [168], last_lr: 0.00058, train_loss: 0.5708, val_loss: 2.5846, val_acc: 0.4982
# Epoch [169], last_lr: 0.00054, train_loss: 0.5643, val_loss: 2.8975, val_acc: 0.4978
# Epoch [170], last_lr: 0.00051, train_loss: 0.5506, val_loss: 2.6609, val_acc: 0.5043
# Epoch [171], last_lr: 0.00048, train_loss: 0.5434, val_loss: 2.6591, val_acc: 0.5020
# Epoch [172], last_lr: 0.00044, train_loss: 0.5256, val_loss: 3.0700, val_acc: 0.4987
# Epoch [173], last_lr: 0.00041, train_loss: 0.5203, val_loss: 2.7727, val_acc: 0.4996
# Epoch [174], last_lr: 0.00038, train_loss: 0.5419, val_loss: 2.9853, val_acc: 0.4965
# Epoch [175], last_lr: 0.00035, train_loss: 0.5159, val_loss: 2.9507, val_acc: 0.4976
# Epoch [176], last_lr: 0.00032, train_loss: 0.5027, val_loss: 2.8044, val_acc: 0.5003
# Epoch [177], last_lr: 0.00030, train_loss: 0.4968, val_loss: 2.7678, val_acc: 0.5030
# Epoch [178], last_lr: 0.00027, train_loss: 0.4839, val_loss: 2.7596, val_acc: 0.5035
# Epoch [179], last_lr: 0.00024, train_loss: 0.4775, val_loss: 2.7300, val_acc: 0.5010
# Epoch [180], last_lr: 0.00022, train_loss: 0.4817, val_loss: 2.7766, val_acc: 0.5044
# Epoch [181], last_lr: 0.00020, train_loss: 0.4795, val_loss: 2.7403, val_acc: 0.5047
# Epoch [182], last_lr: 0.00018, train_loss: 0.4717, val_loss: 2.8688, val_acc: 0.5030
# Epoch [183], last_lr: 0.00016, train_loss: 0.4569, val_loss: 2.8416, val_acc: 0.5014
# Epoch [184], last_lr: 0.00014, train_loss: 0.4567, val_loss: 2.8782, val_acc: 0.5037
# Epoch [185], last_lr: 0.00012, train_loss: 0.4505, val_loss: 2.7559, val_acc: 0.5012
# Epoch [186], last_lr: 0.00010, train_loss: 0.4495, val_loss: 2.8168, val_acc: 0.5019
# Epoch [187], last_lr: 0.00009, train_loss: 0.4466, val_loss: 2.8476, val_acc: 0.5035
# Epoch [188], last_lr: 0.00007, train_loss: 0.4398, val_loss: 2.8133, val_acc: 0.5036
# Epoch [189], last_lr: 0.00006, train_loss: 0.4443, val_loss: 2.9031, val_acc: 0.5048
# Epoch [190], last_lr: 0.00005, train_loss: 0.4426, val_loss: 2.7716, val_acc: 0.5051
# Epoch [191], last_lr: 0.00004, train_loss: 0.4310, val_loss: 2.7959, val_acc: 0.5048
# Epoch [192], last_lr: 0.00003, train_loss: 0.4447, val_loss: 2.8476, val_acc: 0.5056
# Epoch [193], last_lr: 0.00002, train_loss: 0.4356, val_loss: 2.8111, val_acc: 0.5013
# Epoch [194], last_lr: 0.00002, train_loss: 0.4347, val_loss: 2.9421, val_acc: 0.5037
# Epoch [195], last_lr: 0.00001, train_loss: 0.4282, val_loss: 2.8069, val_acc: 0.5042
# Epoch [196], last_lr: 0.00001, train_loss: 0.4402, val_loss: 2.8608, val_acc: 0.5045
# Epoch [197], last_lr: 0.00000, train_loss: 0.4329, val_loss: 2.7470, val_acc: 0.5041
# Epoch [198], last_lr: 0.00000, train_loss: 0.4381, val_loss: 3.0212, val_acc: 0.5017
# Epoch [199], last_lr: 0.00000, train_loss: 0.4368, val_loss: 2.9103, val_acc: 0.5028
# CPU times: user 44min 29s, sys: 5min 35s, total: 50min 5s
# Wall time: 48min 32s

# %% [markdown]
# # Plotting

# %%
def plot_acc(history):
    plt.plot([x["val_acc"] for x in history],"-x")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")

def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history], "-bx")
    plt.plot([x["val_loss"] for x in history],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","val loss"])
    
def plot_lrs(history):
    plt.plot(np.concatenate([x.get("lrs",[]) for x in history]))
    plt.xlabel("Batch number")
    plt.ylabel("Learning rate")

# %%
plot_loss(history)

# %%
plot_acc(history)

# %%
plot_lrs(history)

# %%
import json
import os
file_path = f'adabelief_scratch_lr1e-2.json'
def store_history(history, file_path):
    if not os.path.exists(file_path):
        with open(file_path, 'w') as json_file:
            pass 
    with open(file_path, 'w') as json_file:
        json.dump(history, json_file)

store_history(history, file_path)

# %% [markdown]
# # Make predictions and see the image with its result

# %%
def predict_image(img, model):
    xb = to_device(img.unsqueeze(0), device)
    yb = model(xb)
    _, preds  = torch.max(yb, dim=1)
    return test_data.classes[preds[0].item()]

# %%
img, label = test_data[0]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: mountain , Predicted: road

# %%
img, label = test_data[1002]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: wardrobe , Predicted: wardrobe

# %% [markdown]
# # Save

# %%
torch.save(model.state_dict(), 'adabelief_scratch_lr1e-2.pth')

# %%
print("finish")
# Out:
# finish

# %%
def test_accuracy(model, test_data):

    correct = 0
    for image, label in test_data:
        
        y = predict_image(image, model)
        if y == test_data.classes[label]:
            correct += 1

    return correct/len(test_data)

# %%
test_accuracy(model, test_data)
# Out:
# 0.5023
