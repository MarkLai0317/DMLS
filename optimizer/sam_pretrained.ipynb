# %% [markdown]
# # CIFAR-100 Image Classification using ResNet (Residual Network) in PyTorch
#
# ResNet, short for Residual Network is a specific type of neural network that was introduced in 2015 by Kaiming He, Xiangyu Zhang, Shaoqing Ren and Jian Sun in their paper [“Deep Residual Learning for Image Recognition”](https://arxiv.org/pdf/1512.03385.pdf). <br/>
# ResNet was an innovative approach over VGG-like models:
# * Won 1st place in the ILSVRC 2015 classification competition with a top-5 error rate of 3.57% (An ensemble model)
# * Won the 1st place in ILSVRC and COCO 2015 competition in ImageNet Detection, ImageNet localization, Coco detection and Coco segmentation.
# * Replacing VGG-16 layers in Faster R-CNN with ResNet-101. They observed relative improvements of 28%
# * Efficiently trained networks with 100 layers and 1000 layers also.
#
# We get over 70% accuracy without using any pre-trained model in 100 epochs and it proves the power of ResNet.
#
# In this notebook, I will be implementing less complex version of ResNets to be able to get results in reasonable amount of time. Even though the implementation is done through CIFAR-100 dataset, it can be used with any image classification dataset. <br/>Note: Do not forget to change transform values if you use different the dataset. You can find the best parameters from SOTA implementations for well-known datasets.
#
# #### References which I got implementations and explanations.
# - [weiaicunzai/pytorch-cifar100](https://github.com/weiaicunzai/pytorch-cifar100/blob/master/models/resnet.py)
# - [papers-with-code](https://paperswithcode.com/sota/image-classification-on-cifar-100)
# - [pytorch-basic-cifar10](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)
# - [more-implementation-with-explanations](https://blog.jovian.ai/image-classification-of-cifar100-dataset-using-pytorch-8b7145242df1)
# - [more-reading](https://www.researchgate.net/publication/355698607_MEST_Accurate_and_Fast_Memory-Economic_Sparse_Training_Framework_on_the_Edge)
# - [visualization](https://jovian.ai/damian-c036/cifar100-final-project/v/5?utm_source=embed)
#
#
# So we are good to go.

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import CIFAR100
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split, ConcatDataset
import torchvision.transforms as tt

# %% [markdown]
# ____
# #### Before we load the data, it is required to first prepare the transformations to be applied. It is an important step to prepare the data for training to avoid overfitting problem.
# ____

# %%
stats = ((0.5074,0.4867,0.4411),(0.2011,0.1987,0.2025))
train_transform = tt.Compose([
    tt.RandomHorizontalFlip(),
    tt.RandomCrop(32, padding=4, padding_mode="reflect"),
    tt.ToTensor(),
    tt.Normalize(*stats)
])

test_transform = tt.Compose([
    tt.ToTensor(),
    tt.Normalize(*stats)
])

# %% [markdown]
# ___
# RandomHorizontalFlip randomly flips an image with a probability of 50%, and RandomCrop pads an image by 4 pixel on each side then randomly crops 32x32 from the image after padding. We add such transformations to add noise to the data and prevent our model from overfitting. There are also other transformations you can use such as ColorJitter and RandomVerticalFlip etc. but I found these to be sufficient for our purposes. <br />
#
# ToTensor simply converts the image to a Tensor. Since its a coloured image, it would have 3 channels (R,G,B) so the Tensor would be of size 3x32x32. <br/>
#
# Normalize takes the mean and standard deviation for each channel of the entire dataset as input. Normalizing scales our data to a similar range of values to make sure that our gradients don’t go out of control.
# Now we just prepare our train and test dataset and then we can explore the data.
# ___

# %% [markdown]
# # Loading Data

# %%
train_data = CIFAR100(download=True, root="./data", transform=train_transform)
test_data = CIFAR100(root="./data", train=False, transform=test_transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# _____

# %%
for image, label in train_data:
    print("Image shape: ",image.shape)
    print("Image tensor: ", image)
    print("Label: ", label)
    break
# Out:
# Image shape:  torch.Size([3, 32, 32])
# Image tensor:  tensor([[[ 2.4495,  2.4495,  2.4495,  ..., -0.1636,  0.7140,  1.1625],
#          [ 2.4300,  2.4300,  2.4300,  ...,  0.3240,  0.6165,  0.7920],
#          [ 2.4495,  2.4495,  2.4495,  ...,  1.0260,  1.6110,  1.2795],
#          ...,
#          [ 1.0260,  0.9675,  0.5190,  ..., -0.6706, -0.9436, -1.0996],
#          [ 0.5580,  0.6165,  0.5385,  ..., -0.9631, -1.1581, -1.5676],
#          [ 0.2070,  0.0900,  0.2070,  ..., -1.0411, -1.2556, -1.9381]],
#
#         [[ 2.5833,  2.5833,  2.5833,  ...,  0.1755,  1.0636,  1.4781],
#          [ 2.5636,  2.5636,  2.5636,  ...,  0.5899,  0.8662,  1.0241],
#          [ 2.5833,  2.5833,  2.5833,  ...,  1.3794,  1.9715,  1.5965],
#          ...,
#          [ 1.8925,  1.8136,  1.2807,  ..., -0.7719, -1.1271, -1.3442],
#          [ 1.4781,  1.4978,  1.3004,  ..., -0.9692, -1.2653, -1.7784],
#          [ 1.0833,  0.9649,  1.0044,  ..., -0.9297, -1.2258, -2.1139]],
#
#         [[ 2.7600,  2.7600,  2.7600,  ..., -0.4934,  0.3393,  1.0945],
#          [ 2.7406,  2.7406,  2.7406,  ...,  0.0101,  0.3393,  0.7266],
#          [ 2.7600,  2.7600,  2.7600,  ...,  1.0558,  1.7723,  1.5593],
#          ...,
#          [-0.0480, -0.1255, -0.3192,  ..., -1.2681, -1.5973, -1.6748],
#          [-0.8420, -0.6484, -0.2998,  ..., -1.6748, -1.8491, -2.0233],
#          [-1.0163, -1.1325, -0.7065,  ..., -1.7910, -1.8878, -2.1589]]])
# Label:  19

# %%
train_classes_items = dict()

for train_item in train_data:
    label = train_data.classes[train_item[1]]
    if label not in train_classes_items:
        train_classes_items[label] = 1
    else:
        train_classes_items[label] += 1

train_classes_items
# Out:
# {'cattle': 500,
#  'dinosaur': 500,
#  'apple': 500,
#  'boy': 500,
#  'aquarium_fish': 500,
#  'telephone': 500,
#  'train': 500,
#  'cup': 500,
#  'cloud': 500,
#  'elephant': 500,
#  'keyboard': 500,
#  'willow_tree': 500,
#  'sunflower': 500,
#  'castle': 500,
#  'sea': 500,
#  'bicycle': 500,
#  'wolf': 500,
#  'squirrel': 500,
#  'shrew': 500,
#  'pine_tree': 500,
#  'rose': 500,
#  'television': 500,
#  'table': 500,
#  'possum': 500,
#  'oak_tree': 500,
#  'leopard': 500,
#  'maple_tree': 500,
#  'rabbit': 500,
#  'chimpanzee': 500,
#  'clock': 500,
#  'streetcar': 500,
#  'cockroach': 500,
#  'snake': 500,
#  'lobster': 500,
#  'mountain': 500,
#  'palm_tree': 500,
#  'skyscraper': 500,
#  'tractor': 500,
#  'shark': 500,
#  'butterfly': 500,
#  'bottle': 500,
#  'bee': 500,
#  'chair': 500,
#  'woman': 500,
#  'hamster': 500,
#  'otter': 500,
#  'seal': 500,
#  'lion': 500,
#  'mushroom': 500,
#  'girl': 500,
#  'sweet_pepper': 500,
#  'forest': 500,
#  'crocodile': 500,
#  'orange': 500,
#  'tulip': 500,
#  'mouse': 500,
#  'camel': 500,
#  'caterpillar': 500,
#  'man': 500,
#  'skunk': 500,
#  'kangaroo': 500,
#  'raccoon': 500,
#  'snail': 500,
#  'rocket': 500,
#  'whale': 500,
#  'worm': 500,
#  'turtle': 500,
#  'beaver': 500,
#  'plate': 500,
#  'wardrobe': 500,
#  'road': 500,
#  'fox': 500,
#  'flatfish': 500,
#  'tiger': 500,
#  'ray': 500,
#  'dolphin': 500,
#  'poppy': 500,
#  'porcupine': 500,
#  'lamp': 500,
#  'crab': 500,
#  'motorcycle': 500,
#  'spider': 500,
#  'tank': 500,
#  'orchid': 500,
#  'lizard': 500,
#  'beetle': 500,
#  'bridge': 500,
#  'baby': 500,
#  'lawn_mower': 500,
#  'house': 500,
#  'bus': 500,
#  'couch': 500,
#  'bowl': 500,
#  'pear': 500,
#  'bed': 500,
#  'plain': 500,
#  'trout': 500,
#  'bear': 500,
#  'pickup_truck': 500,
#  'can': 500}

# %%
test_classes_items = dict()
for test_item in test_data:
    label = test_data.classes[test_item[1]]
    if label not in test_classes_items:
        test_classes_items[label] = 1
    else:
        test_classes_items[label] += 1

test_classes_items
# Out:
# {'mountain': 100,
#  'forest': 100,
#  'seal': 100,
#  'mushroom': 100,
#  'sea': 100,
#  'tulip': 100,
#  'camel': 100,
#  'butterfly': 100,
#  'cloud': 100,
#  'apple': 100,
#  'skunk': 100,
#  'streetcar': 100,
#  'rocket': 100,
#  'lamp': 100,
#  'lion': 100,
#  'wolf': 100,
#  'rose': 100,
#  'orange': 100,
#  'dinosaur': 100,
#  'chimpanzee': 100,
#  'can': 100,
#  'keyboard': 100,
#  'bicycle': 100,
#  'chair': 100,
#  'plate': 100,
#  'lawn_mower': 100,
#  'turtle': 100,
#  'palm_tree': 100,
#  'shark': 100,
#  'pickup_truck': 100,
#  'boy': 100,
#  'couch': 100,
#  'house': 100,
#  'porcupine': 100,
#  'cockroach': 100,
#  'clock': 100,
#  'castle': 100,
#  'beaver': 100,
#  'bee': 100,
#  'bottle': 100,
#  'pear': 100,
#  'baby': 100,
#  'flatfish': 100,
#  'oak_tree': 100,
#  'leopard': 100,
#  'snail': 100,
#  'crocodile': 100,
#  'rabbit': 100,
#  'beetle': 100,
#  'girl': 100,
#  'sunflower': 100,
#  'raccoon': 100,
#  'train': 100,
#  'ray': 100,
#  'trout': 100,
#  'bowl': 100,
#  'snake': 100,
#  'orchid': 100,
#  'tractor': 100,
#  'caterpillar': 100,
#  'bus': 100,
#  'mouse': 100,
#  'crab': 100,
#  'sweet_pepper': 100,
#  'maple_tree': 100,
#  'whale': 100,
#  'skyscraper': 100,
#  'pine_tree': 100,
#  'tank': 100,
#  'cattle': 100,
#  'man': 100,
#  'aquarium_fish': 100,
#  'shrew': 100,
#  'plain': 100,
#  'possum': 100,
#  'lobster': 100,
#  'hamster': 100,
#  'television': 100,
#  'dolphin': 100,
#  'worm': 100,
#  'squirrel': 100,
#  'cup': 100,
#  'woman': 100,
#  'bridge': 100,
#  'wardrobe': 100,
#  'road': 100,
#  'lizard': 100,
#  'elephant': 100,
#  'spider': 100,
#  'fox': 100,
#  'otter': 100,
#  'poppy': 100,
#  'willow_tree': 100,
#  'table': 100,
#  'kangaroo': 100,
#  'telephone': 100,
#  'bed': 100,
#  'motorcycle': 100,
#  'bear': 100,
#  'tiger': 100}

# %% [markdown]
# # BATCHSIZE & DataLoader

# %%
BATCH_SIZE = 128
train_dl = DataLoader(train_data, BATCH_SIZE, num_workers=4, pin_memory=True, shuffle=True)
test_dl = DataLoader(test_data, BATCH_SIZE, num_workers=4, pin_memory=True)

# %% [markdown]
# # Visualization

# %%
# for 8 images
train_8_samples = DataLoader(train_data, 8, num_workers=4, pin_memory=True, shuffle=True)

def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize = (20,20))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(train_8_samples)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print(''.join(f'{train_data.classes[labels[j]]:20s}' for j in range(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# flatfish            crocodile           apple               caterpillar         plate               keyboard            tank                fox

# %% [markdown]
# # Get CUDA ready

# %%
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    return torch.device("cpu")

def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device) for x in data]
    return data.to(device,non_blocking=True)


class ToDeviceLoader:
    def __init__(self,data,device):
        self.data = data
        self.device = device
        
    def __iter__(self):
        for batch in self.data:
            yield to_device(batch,self.device)
            
    def __len__(self):
        return len(self.data)

# %%
device = get_device()
print(device)

train_dl = ToDeviceLoader(train_dl, device)
test_dl = ToDeviceLoader(test_dl, device)
# Out:
# cuda

# %%
def accuracy(predicted, actual):
    _, predictions = torch.max(predicted, dim=1)
    return torch.tensor(torch.sum(predictions==actual).item()/len(predictions))

# %% [markdown]
# # BaseModel

# %%
class BaseModel(nn.Module):
    def training_step(self,batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        return loss
    
    def validation_step(self,batch):
        images, labels = batch
        out = self(images)
        loss = F.cross_entropy(out,labels)
        acc = accuracy(out,labels)
        return {"val_loss":loss.detach(),"val_acc":acc}
    
    def validation_epoch_end(self,outputs):
        batch_losses = [loss["val_loss"] for loss in outputs]
        loss = torch.stack(batch_losses).mean()
        batch_accuracy = [accuracy["val_acc"] for accuracy in outputs]
        acc = torch.stack(batch_accuracy).mean()
        return {"val_loss":loss.item(),"val_acc":acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# # ResNet Implementation
#
# BaseModel allows us to check and record the results of our model every time we train and pretty much just helps us keep track of our progress. This is what our actual model will inherit. <br />
#
# I implemented ResNet with changing a little bit that worked better than the one I got and used as base.<br />
#
# #### An example figure of ResNet approach to understand easily what we will see below as code:
#
# ![image.png](attachment:5e638e86-7b48-499f-847d-741d69568111.png)
# <br/><br/><br/><br/>
# ____

# %%
# def conv_shortcut(in_channel, out_channel, stride):
#     layers = [nn.Conv2d(in_channel, out_channel, kernel_size=(1,1), stride=(stride, stride)),
#              nn.BatchNorm2d(out_channel)]
#     return nn.Sequential(*layers)

# def block(in_channel, out_channel, k_size,stride, conv=False):
#     layers = None
    
#     first_layers = [nn.Conv2d(in_channel,out_channel[0], kernel_size=(1,1),stride=(1,1)),
#                     nn.BatchNorm2d(out_channel[0]),
#                     nn.ReLU(inplace=True)]
#     if conv:
#         first_layers[0].stride=(stride,stride)
    
#     second_layers = [nn.Conv2d(out_channel[0], out_channel[1], kernel_size=(k_size, k_size), stride=(1,1), padding=1),
#                     nn.BatchNorm2d(out_channel[1])]

#     layers = first_layers + second_layers
    
#     return nn.Sequential(*layers)
    

# class ResNet(BaseModel):
    
#     def __init__(self, in_channels, num_classes):
#         super().__init__()
        
#         self.stg1 = nn.Sequential(
#                                    nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=(3),
#                                              stride=(1), padding=1),
#                                    nn.BatchNorm2d(64),
#                                    nn.ReLU(inplace=True),
#                                    nn.MaxPool2d(kernel_size=3, stride=2))
        
#         ##stage 2
#         self.convShortcut2 = conv_shortcut(64,256,1)
        
#         self.conv2 = block(64,[64,256],3,1,conv=True)
#         self.ident2 = block(256,[64,256],3,1)

        
#         ##stage 3
#         self.convShortcut3 = conv_shortcut(256,512,2)
        
#         self.conv3 = block(256,[128,512],3,2,conv=True)
#         self.ident3 = block(512,[128,512],3,2)

        
#         ##stage 4
#         self.convShortcut4 = conv_shortcut(512,1024,2)
        
#         self.conv4 = block(512,[256,1024],3,2,conv=True)
#         self.ident4 = block(1024,[256,1024],3,2)
        
        
#         ##Classify
#         self.classifier = nn.Sequential(
#                                        nn.AvgPool2d(kernel_size=(4)),
#                                        nn.Flatten(),
#                                        nn.Linear(1024, num_classes))
        
#     def forward(self,inputs):
#         out = self.stg1(inputs)
        
#         #stage 2
#         out = F.relu(self.conv2(out) + self.convShortcut2(out))
#         out = F.relu(self.ident2(out) + out)
#         out = F.relu(self.ident2(out) + out)
#         out = F.relu(self.ident2(out) + out)
        
#         #stage3
#         out = F.relu(self.conv3(out) + (self.convShortcut3(out)))
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
#         out = F.relu(self.ident3(out) + out)
        
#         #stage4             
#         out = F.relu(self.conv4(out) + (self.convShortcut4(out)))
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
#         out = F.relu(self.ident4(out) + out)
        
#         #Classify
#         out = self.classifier(out)#100x1024
        
#         return out

# %%
# model = ResNet(3,100)
from torchvision import models

class ResNet101Model(BaseModel):
    def __init__(self, num_classes):
        super().__init__()
        self.model = models.resnet101(pretrained=True)
        num_ftrs = self.model.fc.in_features
        self.model.fc = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.model(x)

# %%
model = ResNet101Model(num_classes=100)
model = to_device(model, device)
# Out:
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# # SAM Optimizer

# %%
import torch


class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.1, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self.grad_norm()
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)
            for p in group["params"]:
                if p.grad is None: continue
                e_w = p.grad * scale
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]["e_w"] = e_w

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.sub_(self.state[p]["e_w"])  # get back to "w" from "w + e(w)"

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    def step(self, closure=None):
        raise NotImplementedError("SAM doesn't work like the other optimizers, you should first call `first_step` and the `second_step`; see the documentation for more info.")

    def grad_norm(self):
        norm = torch.norm(
                    torch.stack([
                        p.grad.norm(p=2)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

# %% [markdown]
# # Evaluation & Fit Function for Training

# %%
@torch.no_grad()
def evaluate(model,test_dl):
    model.eval()
    outputs = [model.validation_step(batch) for batch in test_dl]
    return model.validation_epoch_end(outputs)

criterion = nn.CrossEntropyLoss()

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit (epochs, train_dl, test_dl, model, optimizer, max_lr, weight_decay, scheduler, rho, grad_clip=None):
    torch.cuda.empty_cache()
    
    history = []
    
    optimizer = optimizer(
        model.parameters(),
        torch.optim.SGD,
        rho=rho,
        lr=max_lr,
        weight_decay=weight_decay,
    )
    
    scheduler = scheduler(optimizer.base_optimizer, T_max=epochs * len(train_dl))
    
    for epoch in range(epochs):
        model.train()
        
        train_loss = []
        
        lrs = []
        
        for batch in train_dl:
            inputs, targets = batch
            inputs, targets = inputs.to(device), targets.to(device)

            with torch.set_grad_enabled(True):
                # compute output
                outputs = model(inputs)
                batch_loss = criterion(outputs, targets)
                train_loss.append(batch_loss.item())

                # compute gradient and do SGD step
                optimizer.zero_grad()
                batch_loss.backward(retain_graph=True)

                optimizer.first_step(zero_grad=True)

                # second forward-backward pass
                outputs = model(inputs)
                batch_loss = criterion(outputs, targets) 
                batch_loss.backward()
                optimizer.second_step(zero_grad=True)
            
            scheduler.step()
            lrs.append(get_lr(optimizer))
        result = evaluate(model, test_dl)
        result["train_loss"] = torch.tensor(train_loss).mean().item()
        result["lrs"] = lrs
        
        model.epoch_end(epoch,result)
        history.append(result)
        
    return history

# %% [markdown]
# # Hyperparameters
#
# - **max_lr**: is the maximum learning rate that we set for learning rate scheduler. For the learning rate scheduler we used OneCycleLR, which sets the learning rate to a low learning rate, gradually increases it to the max learning rate then goes back to a low learning rate. <br/>
# - **grad_clip**: prevents the gradients to become too large. <br/>
# - **weight_decay**: essentially tries to make the model simple and helps the model generalise better.

# %%
epochs = 200
optimizer = SAM
max_lr = 0.05
grad_clip = 0.1
weight_decay = 5e-3
rho = 0.1
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR

# %% [markdown]
# # Training

# %%
# %%time
history = fit(epochs=epochs, train_dl=train_dl, test_dl=test_dl, model=model, 
              optimizer=optimizer, max_lr=max_lr,
              weight_decay=weight_decay, scheduler=scheduler, rho=rho)
# Out:
# /home/howardkao/anaconda3/envs/dmlsproject/lib/python3.12/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch [0], last_lr: 0.05000, train_loss: 2.9852, val_loss: 2.1412, val_acc: 0.4256
# Epoch [1], last_lr: 0.04999, train_loss: 1.9570, val_loss: 1.7611, val_acc: 0.5211
# Epoch [2], last_lr: 0.04997, train_loss: 1.7225, val_loss: 1.6276, val_acc: 0.5556
# Epoch [3], last_lr: 0.04995, train_loss: 1.5883, val_loss: 1.6278, val_acc: 0.5640
# Epoch [4], last_lr: 0.04992, train_loss: 1.5040, val_loss: 1.5810, val_acc: 0.5700
# Epoch [5], last_lr: 0.04989, train_loss: 1.4901, val_loss: 1.5779, val_acc: 0.5677
# Epoch [6], last_lr: 0.04985, train_loss: 1.4351, val_loss: 1.5958, val_acc: 0.5709
# Epoch [7], last_lr: 0.04980, train_loss: 1.3993, val_loss: 1.6053, val_acc: 0.5645
# Epoch [8], last_lr: 0.04975, train_loss: 1.4044, val_loss: 1.5369, val_acc: 0.5905
# Epoch [9], last_lr: 0.04969, train_loss: 1.3853, val_loss: 1.6103, val_acc: 0.5709
# Epoch [10], last_lr: 0.04963, train_loss: 1.3796, val_loss: 1.5727, val_acc: 0.5747
# Epoch [11], last_lr: 0.04956, train_loss: 1.3771, val_loss: 1.5691, val_acc: 0.5721
# Epoch [12], last_lr: 0.04948, train_loss: 1.3885, val_loss: 1.6331, val_acc: 0.5647
# Epoch [13], last_lr: 0.04940, train_loss: 1.3897, val_loss: 1.6421, val_acc: 0.5653
# Epoch [14], last_lr: 0.04931, train_loss: 1.3906, val_loss: 1.7128, val_acc: 0.5504
# Epoch [15], last_lr: 0.04921, train_loss: 1.3939, val_loss: 1.6851, val_acc: 0.5541
# Epoch [16], last_lr: 0.04911, train_loss: 1.3913, val_loss: 1.5966, val_acc: 0.5818
# Epoch [17], last_lr: 0.04901, train_loss: 1.3936, val_loss: 1.8083, val_acc: 0.5213
# Epoch [18], last_lr: 0.04889, train_loss: 1.3895, val_loss: 1.7407, val_acc: 0.5465
# Epoch [19], last_lr: 0.04878, train_loss: 1.3850, val_loss: 1.6342, val_acc: 0.5701
# Epoch [20], last_lr: 0.04865, train_loss: 1.3845, val_loss: 1.5698, val_acc: 0.5846
# Epoch [21], last_lr: 0.04852, train_loss: 1.3707, val_loss: 1.5661, val_acc: 0.5859
# Epoch [22], last_lr: 0.04839, train_loss: 1.3681, val_loss: 1.6705, val_acc: 0.5682
# Epoch [23], last_lr: 0.04824, train_loss: 1.3647, val_loss: 1.6081, val_acc: 0.5725
# Epoch [24], last_lr: 0.04810, train_loss: 1.3606, val_loss: 1.7370, val_acc: 0.5427
# Epoch [25], last_lr: 0.04794, train_loss: 1.3547, val_loss: 1.7021, val_acc: 0.5484
# Epoch [26], last_lr: 0.04779, train_loss: 1.3479, val_loss: 1.5717, val_acc: 0.5796
# Epoch [27], last_lr: 0.04762, train_loss: 1.3372, val_loss: 1.6540, val_acc: 0.5652
# Epoch [28], last_lr: 0.04745, train_loss: 1.3241, val_loss: 1.5773, val_acc: 0.5815
# Epoch [29], last_lr: 0.04728, train_loss: 1.3202, val_loss: 1.5860, val_acc: 0.5885
# Epoch [30], last_lr: 0.04709, train_loss: 1.3098, val_loss: 1.6385, val_acc: 0.5710
# Epoch [31], last_lr: 0.04691, train_loss: 1.3075, val_loss: 1.5939, val_acc: 0.5811
# Epoch [32], last_lr: 0.04672, train_loss: 1.2943, val_loss: 1.6430, val_acc: 0.5646
# Epoch [33], last_lr: 0.04652, train_loss: 1.2848, val_loss: 1.5836, val_acc: 0.5770
# Epoch [34], last_lr: 0.04632, train_loss: 1.2766, val_loss: 1.6639, val_acc: 0.5641
# Epoch [35], last_lr: 0.04611, train_loss: 1.2733, val_loss: 1.6080, val_acc: 0.5775
# Epoch [36], last_lr: 0.04590, train_loss: 1.2538, val_loss: 1.5448, val_acc: 0.5893
# Epoch [37], last_lr: 0.04568, train_loss: 1.2516, val_loss: 1.4774, val_acc: 0.6088
# Epoch [38], last_lr: 0.04545, train_loss: 1.2436, val_loss: 1.6380, val_acc: 0.5666
# Epoch [39], last_lr: 0.04523, train_loss: 1.2283, val_loss: 1.5477, val_acc: 0.5873
# Epoch [40], last_lr: 0.04499, train_loss: 1.2271, val_loss: 1.5306, val_acc: 0.5884
# Epoch [41], last_lr: 0.04475, train_loss: 1.2147, val_loss: 1.6308, val_acc: 0.5734
# Epoch [42], last_lr: 0.04451, train_loss: 1.2091, val_loss: 1.5263, val_acc: 0.6005
# Epoch [43], last_lr: 0.04426, train_loss: 1.2012, val_loss: 1.5398, val_acc: 0.5949
# Epoch [44], last_lr: 0.04401, train_loss: 1.1961, val_loss: 1.5237, val_acc: 0.5965
# Epoch [45], last_lr: 0.04375, train_loss: 1.1823, val_loss: 1.5341, val_acc: 0.5985
# Epoch [46], last_lr: 0.04349, train_loss: 1.1713, val_loss: 1.5705, val_acc: 0.5856
# Epoch [47], last_lr: 0.04322, train_loss: 1.1657, val_loss: 1.6996, val_acc: 0.5583
# Epoch [48], last_lr: 0.04295, train_loss: 1.1564, val_loss: 1.4936, val_acc: 0.5997
# Epoch [49], last_lr: 0.04268, train_loss: 1.1418, val_loss: 1.4891, val_acc: 0.6078
# Epoch [50], last_lr: 0.04240, train_loss: 1.1359, val_loss: 1.4426, val_acc: 0.6106
# Epoch [51], last_lr: 0.04211, train_loss: 1.1275, val_loss: 1.5945, val_acc: 0.5764
# Epoch [52], last_lr: 0.04183, train_loss: 1.1254, val_loss: 1.4625, val_acc: 0.6088
# Epoch [53], last_lr: 0.04153, train_loss: 1.1130, val_loss: 1.5936, val_acc: 0.5761
# Epoch [54], last_lr: 0.04124, train_loss: 1.1015, val_loss: 1.5699, val_acc: 0.5824
# Epoch [55], last_lr: 0.04094, train_loss: 1.0981, val_loss: 1.4628, val_acc: 0.6120
# Epoch [56], last_lr: 0.04063, train_loss: 1.0879, val_loss: 1.4919, val_acc: 0.6059
# Epoch [57], last_lr: 0.04032, train_loss: 1.0806, val_loss: 1.4552, val_acc: 0.6140
# Epoch [58], last_lr: 0.04001, train_loss: 1.0699, val_loss: 1.5101, val_acc: 0.5945
# Epoch [88], last_lr: 0.02930, train_loss: 0.7737, val_loss: 1.3127, val_acc: 0.6454
# Epoch [89], last_lr: 0.02891, train_loss: 0.7632, val_loss: 1.3554, val_acc: 0.6374
# Epoch [90], last_lr: 0.02852, train_loss: 0.7545, val_loss: 1.3224, val_acc: 0.6434
# Epoch [91], last_lr: 0.02813, train_loss: 0.7353, val_loss: 1.3723, val_acc: 0.6374
# Epoch [92], last_lr: 0.02774, train_loss: 0.7284, val_loss: 1.3780, val_acc: 0.6311
# Epoch [93], last_lr: 0.02735, train_loss: 0.7242, val_loss: 1.3245, val_acc: 0.6479
# Epoch [94], last_lr: 0.02696, train_loss: 0.7057, val_loss: 1.4453, val_acc: 0.6183
# Epoch [95], last_lr: 0.02657, train_loss: 0.6960, val_loss: 1.3154, val_acc: 0.6480
# Epoch [96], last_lr: 0.02618, train_loss: 0.6884, val_loss: 1.2800, val_acc: 0.6550
# Epoch [97], last_lr: 0.02579, train_loss: 0.6741, val_loss: 1.3339, val_acc: 0.6458
# Epoch [98], last_lr: 0.02539, train_loss: 0.6652, val_loss: 1.3523, val_acc: 0.6432
# Epoch [99], last_lr: 0.02500, train_loss: 0.6508, val_loss: 1.3023, val_acc: 0.6469
# Epoch [100], last_lr: 0.02461, train_loss: 0.6398, val_loss: 1.3248, val_acc: 0.6447
# Epoch [101], last_lr: 0.02421, train_loss: 0.6340, val_loss: 1.3729, val_acc: 0.6347
# Epoch [102], last_lr: 0.02382, train_loss: 0.6195, val_loss: 1.3019, val_acc: 0.6535
# Epoch [103], last_lr: 0.02343, train_loss: 0.6097, val_loss: 1.3133, val_acc: 0.6503
# Epoch [104], last_lr: 0.02304, train_loss: 0.5942, val_loss: 1.2932, val_acc: 0.6529
# Epoch [105], last_lr: 0.02265, train_loss: 0.5855, val_loss: 1.2924, val_acc: 0.6546
# Epoch [106], last_lr: 0.02226, train_loss: 0.5744, val_loss: 1.2765, val_acc: 0.6565
# Epoch [107], last_lr: 0.02187, train_loss: 0.5604, val_loss: 1.3078, val_acc: 0.6486
# Epoch [108], last_lr: 0.02148, train_loss: 0.5554, val_loss: 1.2604, val_acc: 0.6615
# Epoch [109], last_lr: 0.02109, train_loss: 0.5448, val_loss: 1.3094, val_acc: 0.6503
# Epoch [110], last_lr: 0.02070, train_loss: 0.5347, val_loss: 1.2885, val_acc: 0.6607
# Epoch [111], last_lr: 0.02032, train_loss: 0.5223, val_loss: 1.3159, val_acc: 0.6504
# Epoch [112], last_lr: 0.01993, train_loss: 0.5171, val_loss: 1.3228, val_acc: 0.6458
# Epoch [113], last_lr: 0.01955, train_loss: 0.5035, val_loss: 1.2566, val_acc: 0.6651
# Epoch [114], last_lr: 0.01916, train_loss: 0.4915, val_loss: 1.2459, val_acc: 0.6658
# Epoch [115], last_lr: 0.01878, train_loss: 0.4789, val_loss: 1.2330, val_acc: 0.6677
# Epoch [116], last_lr: 0.01840, train_loss: 0.4709, val_loss: 1.2622, val_acc: 0.6634
# Epoch [117], last_lr: 0.01803, train_loss: 0.4601, val_loss: 1.2598, val_acc: 0.6631
# Epoch [118], last_lr: 0.01765, train_loss: 0.4530, val_loss: 1.2469, val_acc: 0.6654
# Epoch [119], last_lr: 0.01727, train_loss: 0.4389, val_loss: 1.2389, val_acc: 0.6665
# Epoch [120], last_lr: 0.01690, train_loss: 0.4310, val_loss: 1.2601, val_acc: 0.6652
# Epoch [121], last_lr: 0.01653, train_loss: 0.4208, val_loss: 1.2418, val_acc: 0.6698
# Epoch [122], last_lr: 0.01616, train_loss: 0.4123, val_loss: 1.2510, val_acc: 0.6664
# Epoch [123], last_lr: 0.01580, train_loss: 0.4034, val_loss: 1.2548, val_acc: 0.6665
# Epoch [124], last_lr: 0.01543, train_loss: 0.3950, val_loss: 1.2472, val_acc: 0.6654
# Epoch [125], last_lr: 0.01507, train_loss: 0.3892, val_loss: 1.2359, val_acc: 0.6685
# Epoch [126], last_lr: 0.01471, train_loss: 0.3775, val_loss: 1.2738, val_acc: 0.6618
# Epoch [127], last_lr: 0.01436, train_loss: 0.3722, val_loss: 1.2362, val_acc: 0.6702
# Epoch [128], last_lr: 0.01400, train_loss: 0.3621, val_loss: 1.2263, val_acc: 0.6704
# Epoch [129], last_lr: 0.01365, train_loss: 0.3532, val_loss: 1.2413, val_acc: 0.6670
# Epoch [130], last_lr: 0.01330, train_loss: 0.3424, val_loss: 1.2518, val_acc: 0.6671
# Epoch [131], last_lr: 0.01296, train_loss: 0.3364, val_loss: 1.2374, val_acc: 0.6698
# Epoch [132], last_lr: 0.01261, train_loss: 0.3260, val_loss: 1.2246, val_acc: 0.6748
# Epoch [133], last_lr: 0.01227, train_loss: 0.3175, val_loss: 1.2569, val_acc: 0.6656
# Epoch [134], last_lr: 0.01194, train_loss: 0.3142, val_loss: 1.2632, val_acc: 0.6655
# Epoch [135], last_lr: 0.01160, train_loss: 0.3063, val_loss: 1.2320, val_acc: 0.6713
# Epoch [136], last_lr: 0.01127, train_loss: 0.2989, val_loss: 1.2237, val_acc: 0.6748
# Epoch [137], last_lr: 0.01095, train_loss: 0.2958, val_loss: 1.2109, val_acc: 0.6807
# Epoch [138], last_lr: 0.01062, train_loss: 0.2880, val_loss: 1.2240, val_acc: 0.6754
# Epoch [139], last_lr: 0.01031, train_loss: 0.2798, val_loss: 1.2112, val_acc: 0.6766
# Epoch [140], last_lr: 0.00999, train_loss: 0.2744, val_loss: 1.2134, val_acc: 0.6782
# Epoch [141], last_lr: 0.00968, train_loss: 0.2652, val_loss: 1.2204, val_acc: 0.6787
# Epoch [142], last_lr: 0.00937, train_loss: 0.2594, val_loss: 1.2290, val_acc: 0.6747
# Epoch [143], last_lr: 0.00906, train_loss: 0.2529, val_loss: 1.2134, val_acc: 0.6765
# Epoch [144], last_lr: 0.00876, train_loss: 0.2507, val_loss: 1.2389, val_acc: 0.6727
# Epoch [173], last_lr: 0.00206, train_loss: 0.1483, val_loss: 1.1971, val_acc: 0.6886
# Epoch [174], last_lr: 0.00190, train_loss: 0.1471, val_loss: 1.2073, val_acc: 0.6885
# Epoch [175], last_lr: 0.00176, train_loss: 0.1462, val_loss: 1.1991, val_acc: 0.6912
# Epoch [176], last_lr: 0.00161, train_loss: 0.1453, val_loss: 1.1951, val_acc: 0.6905
# Epoch [177], last_lr: 0.00148, train_loss: 0.1445, val_loss: 1.1943, val_acc: 0.6920
# Epoch [178], last_lr: 0.00135, train_loss: 0.1428, val_loss: 1.1962, val_acc: 0.6936
# Epoch [179], last_lr: 0.00122, train_loss: 0.1433, val_loss: 1.1932, val_acc: 0.6919
# Epoch [180], last_lr: 0.00111, train_loss: 0.1417, val_loss: 1.1878, val_acc: 0.6928
# Epoch [181], last_lr: 0.00099, train_loss: 0.1425, val_loss: 1.1947, val_acc: 0.6930
# Epoch [182], last_lr: 0.00089, train_loss: 0.1405, val_loss: 1.1990, val_acc: 0.6923
# Epoch [183], last_lr: 0.00079, train_loss: 0.1395, val_loss: 1.1957, val_acc: 0.6935
# Epoch [184], last_lr: 0.00069, train_loss: 0.1386, val_loss: 1.1950, val_acc: 0.6931
# Epoch [185], last_lr: 0.00060, train_loss: 0.1393, val_loss: 1.1936, val_acc: 0.6965
# Epoch [186], last_lr: 0.00052, train_loss: 0.1377, val_loss: 1.1929, val_acc: 0.6913
# Epoch [187], last_lr: 0.00044, train_loss: 0.1378, val_loss: 1.1912, val_acc: 0.6949
# Epoch [188], last_lr: 0.00037, train_loss: 0.1371, val_loss: 1.1940, val_acc: 0.6918
# Epoch [189], last_lr: 0.00031, train_loss: 0.1370, val_loss: 1.1949, val_acc: 0.6936
# Epoch [190], last_lr: 0.00025, train_loss: 0.1374, val_loss: 1.1970, val_acc: 0.6939
# Epoch [191], last_lr: 0.00020, train_loss: 0.1361, val_loss: 1.1962, val_acc: 0.6918
# Epoch [192], last_lr: 0.00015, train_loss: 0.1367, val_loss: 1.1937, val_acc: 0.6934
# Epoch [193], last_lr: 0.00011, train_loss: 0.1361, val_loss: 1.1932, val_acc: 0.6943
# Epoch [194], last_lr: 0.00008, train_loss: 0.1363, val_loss: 1.1975, val_acc: 0.6955
# Epoch [195], last_lr: 0.00005, train_loss: 0.1359, val_loss: 1.1930, val_acc: 0.6931
# Epoch [196], last_lr: 0.00003, train_loss: 0.1364, val_loss: 1.2020, val_acc: 0.6911
# Epoch [197], last_lr: 0.00001, train_loss: 0.1355, val_loss: 1.1949, val_acc: 0.6951
# Epoch [198], last_lr: 0.00000, train_loss: 0.1366, val_loss: 1.1938, val_acc: 0.6953
# Epoch [199], last_lr: 0.00000, train_loss: 0.1366, val_loss: 1.1918, val_acc: 0.6939
# CPU times: user 54min 38s, sys: 7min 3s, total: 1h 1min 42s
# Wall time: 1h 23s

# %% [markdown]
# # Plotting

# %%
def plot_acc(history):
    plt.plot([x["val_acc"] for x in history],"-x")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")

def plot_loss(history):
    plt.plot([x.get("train_loss") for x in history], "-bx")
    plt.plot([x["val_loss"] for x in history],"-rx")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["train loss","val loss"])
    
def plot_lrs(history):
    plt.plot(np.concatenate([x.get("lrs",[]) for x in history]))
    plt.xlabel("Batch number")
    plt.ylabel("Learning rate")

# %%
plot_loss(history)

# %%
plot_acc(history)

# %%
plot_lrs(history)

# %%
import json
import os
file_path = f'sam_pretrained.json'
def store_history(history, file_path):
    if not os.path.exists(file_path):
        with open(file_path, 'w') as json_file:
            pass 
    with open(file_path, 'w') as json_file:
        json.dump(history, json_file)

store_history(history, file_path)

# %% [markdown]
# # Make predictions and see the image with its result

# %%
def predict_image(img, model):
    xb = to_device(img.unsqueeze(0), device)
    yb = model(xb)
    _, preds  = torch.max(yb, dim=1)
    return test_data.classes[preds[0].item()]

# %%
img, label = test_data[0]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: mountain , Predicted: road

# %%
img, label = test_data[1002]
plt.imshow(img.permute(1, 2, 0))
print('Label:', test_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: wardrobe , Predicted: wardrobe

# %% [markdown]
# # Save

# %%
torch.save(model.state_dict(), 'sam_pretrained.pth')

# %%
print("finish")
# Out:
# finish

# %%
def test_accuracy(model, test_data):

    correct = 0
    for image, label in test_data:
        
        y = predict_image(image, model)
        if y == test_data.classes[label]:
            correct += 1

    return correct/len(test_data)

# %%
test_accuracy(model, test_data)
# Out:
# 0.6939
